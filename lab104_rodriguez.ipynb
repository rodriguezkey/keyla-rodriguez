# %% [markdown]
# <a href="https://colab.research.google.com/github/rodriguezkey/keyla-rodriguez/blob/main/lab104_rodriguez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# # creacion de dataframe

# %%
import pandas as pd

# %%
data = [[1,"hugo",20],[2,"paco",18],[3,"luis",17],[4,"daniel",16],[5,"carlos",15]]
df=pd.DataFrame(data, columns=["id","name","age"])
print(df)
# Out:
#    id    name  age
# 0   1    hugo   20
# 1   2    paco   18
# 2   3    luis   17
# 3   4  daniel   16
# 4   5  carlos   15

# %% [markdown]
# # CSV

# %%
import pandas as pd
path ="/content/sample_data/california_housing_train.csv"
df = pd.read_csv(path)
df.describe(include='all').round(1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.4      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# ...

# %% [markdown]
# # Montaje de Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
