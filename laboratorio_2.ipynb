# %% [markdown]
# <a href="https://colab.research.google.com/github/rodriguezkey/keyla-rodriguez/blob/main/laboratorio_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2.-Hacer uso de la función info()

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"

df= pd.read_csv(path)
df.info()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-5-5326e8f77f2d>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(path)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121995 entries, 0 to 121994
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   fecha                       121995 non-null  object
#  1   agencia                     120918 non-null  object
#  2   usuaria_sexo                121591 non-null  object
#  3   usuaria_nacionalidad        121641 non-null  object
#  4   usuaria_ent_fed_nacimiento  119967 non-null  object
#  5   usuaria_estado_civil        88051 non-null   object
#  6   usuaria_edad                120005 non-null  float64
#  7   usuaria_hijas               108979 non-null  float64
#  8   usuaria_hijos               102770 non-null  float64
#  9   usuaria_hijes               108646 non-null  float64
#  10  relacion_con_agresora       73933 non-null   object
#  11  agresora_ocupacion          42172 non-null   object
#  12  ci_iniciada                 99815 non-null   object
#  13  delito                      42187 non-null   object
#  14  representacion              116772 non-null  object
#  15  violencia_modalidad         107400 non-null  object
#  16  solicitud_medidas           40349 non-null   object
#  17  alto_riesgo                 52963 non-null   object
#  18  riesgo_feminicida           54000 non-null   object
#  19  vio_psicoemocional          121995 non-null  object
#  20  vio_fisica                  121995 non-null  object
#  21  vio_economica               121995 non-null  object
#  22  vio_patrimonial             121995 non-null  object
#  23  vio_sexual                  121995 non-null  object
#  24  vio_simbolica               121995 non-null  object
#  25  vio_obstetrica              121995 non-null  object
#  26  vio_reproductivos           121995 non-null  object
#  27  vio_feminicida              121995 non-null  object
# dtypes: float64(4), object(24)
# memory usage: 26.1+ MB

# %% [markdown]
# # 3.-Verificar lectura de archivo tail

# %%
import pandas as pd
path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"
df=pd.read_csv(path)
df.tail(10)
# Out:
# <ipython-input-7-0c63b8856639>:3: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)
#              fecha agencia usuaria_sexo usuaria_nacionalidad  \
# 121985  2022-03-01   COY-4        MUJER             MEXICANA
# 121986  2022-03-01   COY-4        MUJER             MEXICANA
# 121987  2022-03-01   COY-4        MUJER             MEXICANA
# 121988  2022-03-01   COY-4        MUJER             MEXICANA
# 121989  2022-03-01   COY-4        MUJER             MEXICANA
# 121990  2022-03-01    FIVF        MUJER             MEXICANA
# 121991  2022-03-01   COY-5        MUJER             MEXICANA
# 121992  2022-03-01   COY-5        MUJER             MEXICANA
# 121993  2022-03-01   COY-5        MUJER             MEXICANA
# 121994  2022-03-01   COY-5        MUJER             MEXICANA
#
#              usuaria_ent_fed_nacimiento       usuaria_estado_civil  \
# 121985                           COLIMA                 SOLTERA(O)
# 121986                           PUEBLA  UNIÓN LIBRE O CONCUBINATO
# 121987                           COLIMA                  CASADA(O)
# 121988                           COLIMA                  CASADA(O)
# 121989                           COLIMA                 SOLTERA(O)
# 121990                           COLIMA  UNIÓN LIBRE O CONCUBINATO
# 121991  VERACRUZ DE IGNACIO DE LA LLAVE                 SOLTERA(O)
# 121992                          JALISCO                 SOLTERA(O)
# 121993                           COLIMA                 SOLTERA(O)
# 121994  VERACRUZ DE IGNACIO DE LA LLAVE                 SOLTERA(O)
#
#         usuaria_edad  usuaria_hijas  usuaria_hijos  usuaria_hijes  ...  \
# 121985          36.0            2.0            2.0            2.0  ...
# 121986          57.0            1.0            0.0            1.0  ...
# 121987          30.0            1.0            2.0            3.0  ...
# 121988          28.0            4.0            4.0            4.0  ...
# 121989          62.0            0.0            0.0            0.0  ...
# 121990          50.0            1.0            2.0            3.0  ...
# 121991          31.0            0.0            0.0            0.0  ...
# 121992          20.0            1.0            0.0            1.0  ...
# 121993          26.0            0.0            0.0            0.0  ...
# 121994          31.0            0.0            0.0            0.0  ...
#
#        riesgo_feminicida vio_psicoemocional vio_fisica vio_economica  \
# 121985                NO                 Sí         Sí            No
# 121986                NO                 Sí         Sí            No
# 121987                NO                 No         No            No
# 121988                NO                 Sí         No            No
# 121989                NO                 Sí         No            No
# 121990                NO                 Sí         No            No
# 121991                NO                 Sí         Sí            No
# 121992                NO                 Sí         No            No
# 121993                NO                 Sí         Sí            No
# 121994                NO                 Sí         Sí            No
#
#        vio_patrimonial vio_sexual vio_simbolica vio_obstetrica  \
# 121985              No         No            No             No
# 121986              No         No            No             No
# 121987              No         No            No             No
# 121988              No         No            No             No
# 121989              No         No            No             No
# 121990              No         No            No             No
# 121991              Sí         No            No             No
# 121992              No         No            No             No
# 121993              No         No            No             No
# 121994              Sí         No            No             No
#
#        vio_reproductivos vio_feminicida
# 121985                No             No
# 121986                No             No
# 121987                No             No
# 121988                No             No
# 121989                No             No
# 121990                No             No
# 121991                No             No
# 121992                No             No
# 121993                No             No
# 121994                No             No
#
# [10 rows x 28 columns]

# %% [markdown]
# # 1.-Verificar lectura de archivo CSV

# %%
import pandas as pd
path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"
df=pd.read_csv(path)
registros =df.shape[0]
print(registros)
# Out:
# 121995
# <ipython-input-8-0bf0e3a8a151>:3: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)

# %% [markdown]
# # 4. Obtener el rango de fechas

# %%
import pandas as pd
path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"
df["fecha"]=pd.to_datetime(df["fecha"], format="%Y-%m-%d")
fecha_inicial= df["fecha"].min()
fecha_final= df["fecha"].max()
print(f"el rango de fecha es del{fecha_inicial}al{fecha_final}")
# Out:
# el rango de fecha es del2019-03-01 00:00:00al2022-03-01 00:00:00

# %% [markdown]
# # 5. Obtener la media aritmética

# %%
import pandas as pd
import matplotlib.pyplot as plt
path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"
df = pd.read_csv(path)
media =df["usuaria_edad"].mean()
print(media)
# Out:
# 38.38658389233782
# <ipython-input-20-d8d23be5cae8>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %% [markdown]
# # 6. Obtener la moda

# %%
import pandas as pd
import matplotlib.pyplot as plt
path="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"
df = pd.read_csv(path)
moda = df["usuaria_edad"].mode()
print(moda)
# Out:
# 0    30.0
# Name: usuaria_edad, dtype: float64
# <ipython-input-23-7efe0822c6b6>:4: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
