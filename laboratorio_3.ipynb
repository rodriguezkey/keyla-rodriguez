# %% [markdown]
# <a href="https://colab.research.google.com/github/rodriguezkey/keyla-rodriguez/blob/main/laboratorio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # laboratorio 3

# %%
import pandas as pd

import matplotlib.pyplot as plt

path ="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"

df = pd.read_csv(path)

edad = df["usuaria_edad"]

dist = edad.value_counts()

plt.bar(dist.index, dist.values)

plt.xlim(0,100)

plt.show()
# Out:
# <ipython-input-6-b2730eb6c3c8>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd

import matplotlib.pyplot as plt

path ="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1).csv"

df = pd.read_csv(path)
conteo = df["usuaria_estado_civil"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-11-ab7fc67bd18b>:7: DtypeWarning: Columns (11,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1) - atenciones_abogadas_de_las_mujeres (1) (1).csv"
df = pd.read_csv(path)
#df.info()

conteo = df["anio"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
# Out:
# <ipython-input-17-1b06cbeb48cf>:4: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt
path ="/content/drive/MyDrive/conjunto de datos /atenciones_abogadas_de_las_mujeres (1) - atenciones_abogadas_de_las_mujeres (1) (1).csv"
conteo = df["anio_mes"].value_counts()
plt.barh( conteo.index, conteo)
plt.show()
